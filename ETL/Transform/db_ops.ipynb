# %%
import time

from pymongo import MongoClient
from pymongo.database import Database
from pymongo.collection import Collection, ReturnDocument
from pymongo.errors import ConnectionFailure, InvalidDocument, DuplicateKeyError, OperationFailure, ConfigurationError
from urllib.parse import quote

from config import user, password, socket_path, host, port

# %%
def Client(host=None, port=None, uri=None):
    ''' Create and return a pymongo MongoClient object. Connect with the given parameters if possible, switch to local if the
    remote connection is not possible, using the default host and port.
    
    :param host: the local host to be used. defaults within to localhost
    :type host: sting
    :param port: the local port to be used. defaults within to 27017
    :type port: int
    :param uri: the remote server URI. must be uri encoded
    type uri: uri encoded sting'''
    
    if host and port:
        try:
            client = MongoClient(host=host, port=port)
            return client
        except ConnectionFailure:
            # connect to the remote server if a valid uri is given
            if uri:
                print('caught ConnectionFailure on local server. Trying to make it with remote')
                client = MongoClient(uri)
                print(f'established remote MongoClient on URI={uri}')
                return client
            print('caught ConnectionFailure on local server. Returning None')
            return None
    elif uri:
        # verify that the connection with the remote server is active and switch to the local server if it's not
        try:
            client = MongoClient(uri)
            return client
        except ConfigurationError:
            print(f'Caught configurationError in client() for URI={uri}. It was likely triggered by a DNS timeout.')
            client = MongoClient(host=host, port=port)
            print('connection made with local server, even though you asked for the remote server')
            return client

def dbncol(client, collection, database='test'):
    ''' Make a connection to the database and collection given in the arguments.

    :param client: a MongoClient instance
    :type client: pymongo.MongoClient
    :param database: the name of the database to be used. It must be a database name present at the client
    :type database: str
    :param collection: the database collection to be used.  It must be a collection name present in the database
    :type collection: str
    
    :return col: the collection to be used
    :type: pymongo.collection.Collection
    '''

    db = Database(client, database)
    col = Collection(db, collection)
    return col

def move_sorted(client, from_db, from_col, to_db, to_col, id_list):
    ''' Move the documents from the active database to the archive database.
    Once the forecasted and observed weather objects are sorted into instant documents and loaded 
    to the insants collection they can be moved for permanent storage to another database that will 
    contain only previously sorted weather documents.
    '''

    from_db = from_db
    from_col = from_col
    to_db = to_db
    to_col = to_col

    from_collection = datollection(client, from_db, form_col)
    to_collection = datollection(client, to_db, to_col)

    deleted = from_collection.delete_many(id_list)
    print(type(deleted))
    inserted = to_collection.insert_many(deleted)
    print(type(inserted))
    
def load(data, client, database, collection):
    ''' Load data to specified database collection. Also checks for a preexisting document with the same instant and 
    zipcode, and updates it in the case that there was already one there.

    :param data: the dictionary created from the api calls
    :type data: dict
    :param client: a MongoClient instance
    :type client: pymongo.MongoClient
    :param database: the database to be used
    :type database: str
    :param collection: the database collection to be used
    :type collection: str
    '''

    col = dbncol(client, collection, database='test1')

    # set the appropriate database collections, filters and update types
    if collection == 'instant':
        filters = {'zipcode':data['zipcode'], 'instant':data['instant']}
        updates = {'$push': {'forecasts': data}} # append the forecast object to the forecasts list
        try:
            # check to see if there is a document that fits the parameters. If there is, update it, if there isn't, upsert it
            return col.find_one_and_update(filters, updates,  upsert=True)
        except DuplicateKeyError:
            return(f'DuplicateKeyError, could not insert data into {collection}.')
    elif collection == 'observed' or collection == 'forecasted':
        try:
            col.insert_one(data)
            return
        except DuplicateKeyError:
            return(f'DuplicateKeyError, could not insert data into {collection}.')
    else:
        try:
            filters = {'zipcode':data['zipcode'], 'instant':data['instant']}
            updates = {'$set': {'forecasts': data}} # append the forecast object to the forecasts list
            return col.find_one_and_update(filters, updates,  upsert=True)
        except DuplicateKeyError:
            return(f'DuplicateKeyError, could not insert data into {collection}.')

# %%
if __name__ == "__main__":
    host = host
    port = port
    database = 'OWM'
    collection = 'instant'

    client = Client(host=host, port=port)
    col = dbncol(client, database=database, collection=collection)
    updated_doc_ids = []
    result = col.find({}).batch_size(10)
    r = result
    # change each document in restored instant collection. ** many, maybe all, the documents have all the fields for the observation
    # separtely key'd in the parent document. This will put each of those weather fields together under the field 'observation'
    from pprint import pprint
    n = 0
    fs_and_us = {'passed' : 0, 'replaced' : 0, 'updated' : 0} # for counting the loop results
    for item in r:
        if n%200 == 0:
            print(f'processed {n} documents')
        try:
            ref_time = item.pop('reference_time')
            item['observed'] = {
                'clouds' : item.pop('clouds'),
                'detailed_status' : item.pop('detailed_status'),
                'humidity' : item.pop('humidity'),
                'pressure' : item.pop('pressure'),
                'rain' : item.pop('rain'),
                'snow' : item.pop('snow'),
                'status' : item.pop('status'),
                'temperature' : item.pop('temperature'),
                'weather_code' : item.pop('weather_code'),
                'wind' : item.pop('wind'),
                'time_to_instant': item['instant']-ref_time
            }
            n+=1
        except KeyError:
            fs_and_us['passed'] += 1
            n+=1
            continue
        filters = {'zipcode':item['zipcode'], 'instant':item['instant']}
        updates = {'$set': item}
        try:
            col.find_one_and_replace(filters, item, upsert=True)
    #         print('found and replaced')
            fs_and_us['replaced'] += 1
        except DuplicateKeyError:
            col.find_one_and_update(filters, updates, upsert=True)
            fs_and_us['updated'] += 1
        n += 1
# Out:
# processed 0 documents
# processed 200 documents
# processed 400 documents
# processed 600 documents
# processed 800 documents
# processed 1000 documents
# processed 1200 documents
# processed 1400 documents
# processed 1600 documents
# processed 1800 documents
# processed 2000 documents
# processed 2200 documents
# processed 2400 documents
# processed 2600 documents
# processed 2800 documents
# processed 3000 documents
# processed 3200 documents
# processed 3400 documents
# processed 3600 documents
# processed 3800 documents
# processed 4000 documents
# processed 4200 documents
# processed 4400 documents
# processed 4600 documents
# processed 4800 documents
# processed 5000 documents
# processed 5200 documents
# processed 5400 documents
# processed 5600 documents
# processed 5800 documents
# processed 6000 documents
# processed 6200 documents
# processed 6400 documents
# processed 6600 documents
# processed 6800 documents
# processed 7000 documents
# processed 7200 documents
# processed 7400 documents
# processed 7600 documents
# processed 7800 documents
# processed 8000 documents
# processed 8200 documents
# processed 8400 documents
# processed 8600 documents
# processed 8800 documents
# processed 9000 documents
# processed 9200 documents
# processed 9400 documents
# processed 9600 documents
# processed 9800 documents
# processed 10000 documents
# processed 10200 documents
# processed 10400 documents
# processed 10600 documents
# processed 10800 documents
# processed 11000 documents
# processed 11200 documents
# processed 11400 documents
# processed 11600 documents
# processed 11800 documents
# processed 12000 documents
# processed 12200 documents
# processed 12400 documents
# processed 12600 documents
# processed 12800 documents
# processed 13000 documents
# processed 13200 documents
# processed 13400 documents
# processed 13600 documents
# processed 13800 documents
# processed 14000 documents
# processed 14200 documents
# processed 14400 documents
# processed 14600 documents
# processed 14800 documents
# processed 15000 documents
# processed 15200 documents
# processed 15400 documents
# processed 15600 documents
# processed 15800 documents
# processed 16000 documents
# processed 16200 documents
# processed 16400 documents
# processed 16600 documents
# processed 16800 documents
# processed 17000 documents
# processed 17200 documents
# processed 17400 documents
# processed 17600 documents
# processed 17800 documents
# processed 18000 documents
# processed 18200 documents
# processed 18400 documents
# processed 18600 documents
# processed 18800 documents
# processed 19000 documents
# processed 19200 documents
# processed 19400 documents
# processed 19600 documents
# processed 19800 documents
# processed 20000 documents
# processed 20200 documents
# processed 20400 documents
# processed 20600 documents
# processed 20800 documents
# processed 21000 documents
# processed 21200 documents
# processed 21400 documents
# processed 21600 documents
# processed 21800 documents
# processed 22000 documents
# processed 22200 documents
# processed 22400 documents
# processed 22600 documents
# processed 22800 documents
# processed 23000 documents
# processed 23200 documents
# processed 23400 documents
# processed 23600 documents
# processed 23800 documents
# processed 24000 documents
# processed 24200 documents
# processed 24400 documents
# processed 24600 documents
# processed 24800 documents
# processed 25000 documents
# processed 25200 documents
# processed 25400 documents
# processed 25600 documents
# processed 25800 documents
# processed 26000 documents
# processed 26200 documents
# processed 26400 documents
# processed 26600 documents
# processed 26800 documents
# processed 27000 documents
# processed 27200 documents
# processed 27400 documents
# processed 27600 documents
# processed 27800 documents
# processed 28000 documents
# processed 28200 documents
# processed 28400 documents
# processed 28600 documents
# processed 28800 documents
# processed 29000 documents
# processed 29200 documents
# processed 29400 documents
# processed 29600 documents
# processed 29800 documents
# processed 30000 documents
# processed 30200 documents
# processed 30400 documents
# processed 30600 documents
# processed 30800 documents
# processed 31000 documents
# processed 31200 documents
# processed 31400 documents
# processed 31600 documents
# processed 31800 documents
# processed 32000 documents
# processed 32200 documents
# processed 32400 documents
# processed 32600 documents
# processed 32800 documents
# processed 33000 documents
# processed 33200 documents
# processed 33400 documents
# processed 33600 documents
# processed 33800 documents
# processed 34000 documents
# processed 34200 documents
# processed 34400 documents
# processed 34600 documents
# processed 34800 documents
# processed 35000 documents
# processed 35200 documents
# processed 35400 documents
# processed 35600 documents
# processed 35800 documents
# processed 36000 documents
# processed 36200 documents
# processed 36400 documents
# processed 36600 documents
# processed 36800 documents
# processed 37000 documents
# processed 37200 documents
# processed 37400 documents
# processed 37600 documents
# processed 37800 documents
# processed 38000 documents
# processed 38200 documents
# processed 38400 documents
# processed 38600 documents
# processed 38800 documents
# processed 39000 documents
# processed 39200 documents
# processed 39400 documents
# processed 39600 documents
# processed 39800 documents
# processed 40000 documents
# processed 40200 documents
# processed 40400 documents
# processed 40600 documents
# processed 40800 documents
# processed 41000 documents
# processed 41200 documents
# processed 41400 documents
# processed 41600 documents
# processed 41800 documents
# processed 42000 documents
# processed 42200 documents
# processed 42400 documents
# processed 42600 documents
# processed 42800 documents
# processed 43000 documents
# processed 43200 documents
# processed 43400 documents
# processed 43600 documents
# processed 43800 documents
# processed 44000 documents
# processed 44200 documents
# processed 44400 documents
# processed 44600 documents
# processed 44800 documents
# processed 45000 documents
# processed 45200 documents
# processed 45400 documents
# processed 45600 documents
# processed 45800 documents
# processed 46000 documents
# processed 46200 documents
# processed 46400 documents
# processed 46600 documents
# processed 46800 documents
# processed 47000 documents
# processed 47200 documents
# processed 47400 documents
# processed 47600 documents
# processed 47800 documents
# processed 48000 documents
# processed 48200 documents
# processed 48400 documents
# processed 48600 documents
# processed 48800 documents
# processed 49000 documents
# processed 49200 documents
# processed 49400 documents
# processed 49600 documents
# processed 49800 documents
# processed 50000 documents
# processed 50200 documents
# processed 50400 documents
# processed 50600 documents
# processed 50800 documents
# processed 51000 documents
# processed 51200 documents
# processed 51400 documents
# processed 51600 documents
# processed 51800 documents
# processed 52000 documents
# processed 52200 documents
# processed 52400 documents
# processed 52600 documents
# processed 52800 documents
# processed 53000 documents
# processed 53200 documents
# processed 53400 documents
# processed 53600 documents
# processed 53800 documents
# processed 54000 documents
# processed 54200 documents
# processed 54400 documents
# processed 54600 documents
# processed 54800 documents
# processed 55000 documents
# processed 55200 documents
# processed 55400 documents
# processed 55600 documents
# processed 55800 documents
# processed 56000 documents
# processed 56200 documents
# processed 56400 documents
# processed 56600 documents
# processed 56800 documents
# processed 57000 documents
# processed 57200 documents
# processed 57400 documents
# processed 57600 documents
# processed 57800 documents
# processed 58000 documents
# processed 58200 documents
# processed 58400 documents
# processed 58600 documents
# processed 58800 documents
# processed 59000 documents
# processed 59200 documents
# processed 59400 documents
# processed 59600 documents
# processed 59800 documents
# processed 60000 documents
# processed 60200 documents
# processed 60400 documents
# processed 60600 documents
# processed 60800 documents
# processed 61000 documents
# processed 61200 documents
# processed 61400 documents
# processed 61600 documents
# processed 61800 documents
# processed 62000 documents
# processed 62200 documents
# processed 62400 documents
# processed 62600 documents
# processed 62800 documents
# processed 63000 documents
# processed 63200 documents
# processed 63400 documents
# processed 63600 documents
# processed 63800 documents
# processed 64000 documents
# processed 64200 documents
# processed 64400 documents
# processed 64600 documents
# processed 64800 documents
# processed 65000 documents
# processed 65200 documents
# processed 65400 documents
# processed 65600 documents
# processed 65800 documents
# processed 66000 documents
# processed 66200 documents
# processed 66400 documents
# processed 66600 documents
# processed 66800 documents
# processed 67000 documents
# processed 67200 documents
# processed 67400 documents
# processed 67600 documents
# processed 67800 documents
# processed 68000 documents
# processed 68200 documents
# processed 68400 documents
# processed 68600 documents
# processed 68800 documents
# processed 69000 documents
# processed 69200 documents
# processed 69400 documents
# processed 69600 documents
# processed 69800 documents
# processed 70000 documents
# processed 70200 documents
# processed 70400 documents
# processed 70600 documents
# processed 70800 documents
# processed 71000 documents
# processed 71200 documents
# processed 71400 documents
# processed 71600 documents
# processed 71800 documents
# processed 72000 documents
# processed 72200 documents
# processed 72400 documents
# processed 72600 documents
# processed 72800 documents
# processed 73000 documents
# processed 73200 documents
# processed 73400 documents
# processed 73600 documents
# processed 73800 documents
# processed 74000 documents
# processed 74200 documents
# processed 74400 documents
# processed 74600 documents
# processed 74800 documents
# processed 75000 documents
# processed 75200 documents
# processed 75400 documents
# processed 75600 documents
# processed 75800 documents
# processed 76000 documents
# processed 76200 documents
# processed 76400 documents
# processed 76600 documents
# processed 76800 documents
# processed 77000 documents
# processed 77200 documents
# processed 77400 documents
# processed 77600 documents
# processed 77800 documents
# processed 78000 documents
# processed 78200 documents
# processed 78400 documents
# processed 78600 documents
# processed 78800 documents
# processed 79000 documents
# processed 79200 documents
# processed 79400 documents
# processed 79600 documents
# processed 79800 documents
# processed 80000 documents
# processed 80200 documents
# processed 80400 documents
# processed 80600 documents
# processed 80800 documents
# processed 81000 documents
# processed 81200 documents
# processed 81400 documents
# processed 81600 documents
# processed 81800 documents
# processed 82000 documents
# processed 82200 documents
# processed 82400 documents
# processed 82600 documents
# processed 82800 documents
# processed 83000 documents
# processed 83200 documents
# processed 83400 documents
# processed 83600 documents
# processed 83800 documents
# processed 84000 documents
# processed 84200 documents
# processed 84400 documents
# processed 84600 documents
# processed 84800 documents
# processed 85000 documents
# processed 85200 documents
# processed 85400 documents
# processed 85600 documents
# processed 85800 documents
# processed 86000 documents
# processed 86200 documents
# processed 86400 documents
# processed 86600 documents
# processed 86800 documents
# processed 87000 documents
# processed 87200 documents
# processed 87400 documents
# processed 87600 documents
# processed 87800 documents
# processed 88000 documents
# processed 88200 documents
# processed 88400 documents
# processed 88600 documents
# processed 88800 documents
# processed 89000 documents
# processed 89200 documents
# processed 89400 documents
# processed 89600 documents
# processed 89800 documents
# processed 90000 documents
# processed 90200 documents
# processed 90400 documents
# processed 90600 documents
# processed 90800 documents
# processed 91000 documents
# processed 91200 documents
# processed 91400 documents
# processed 91600 documents
# processed 91800 documents
# processed 92000 documents
# processed 92200 documents
# processed 92400 documents
# processed 92600 documents
# processed 92800 documents
# processed 93000 documents
# processed 93200 documents
# processed 93400 documents
# processed 93600 documents
# processed 93800 documents
# processed 94000 documents
# processed 94200 documents
# processed 94400 documents
# processed 94600 documents
# processed 94800 documents
# processed 95000 documents
# processed 95200 documents
# processed 95400 documents
# processed 95600 documents
# processed 95800 documents
# processed 96000 documents
# processed 96200 documents
# processed 96400 documents
# processed 96600 documents
# processed 96800 documents
# processed 97000 documents
# processed 97200 documents
# processed 97400 documents
# processed 97600 documents
# processed 97800 documents
# processed 98000 documents
# processed 98200 documents
# processed 98400 documents
# processed 98600 documents
# processed 98800 documents
# processed 99000 documents
# processed 99200 documents
# processed 99400 documents
# processed 99600 documents
# processed 99800 documents
# processed 100000 documents
# processed 100200 documents
# processed 100400 documents
# processed 100600 documents
# processed 100800 documents
# processed 101000 documents
# processed 101200 documents
# processed 101400 documents
# processed 101600 documents
# processed 101800 documents
# processed 102000 documents
# processed 102200 documents
# processed 102400 documents
# processed 102600 documents
# processed 102800 documents
# processed 103000 documents
# processed 103200 documents
# processed 103400 documents
# processed 103600 documents
# processed 103800 documents
# processed 104000 documents
# processed 104200 documents
# processed 104400 documents
# processed 104600 documents
# processed 104800 documents
# processed 105000 documents
# processed 105200 documents
# processed 105400 documents
# processed 105600 documents
# processed 105800 documents
# processed 106000 documents
# processed 106200 documents
# processed 106400 documents
# processed 106600 documents
# processed 106800 documents
# processed 107000 documents
# processed 107200 documents
# processed 107400 documents
# processed 107600 documents
# processed 107800 documents
# processed 108000 documents
# processed 108200 documents
# processed 108400 documents
# processed 108600 documents
# processed 108800 documents
# processed 109000 documents
# processed 109200 documents
# processed 109400 documents
# processed 109600 documents
# processed 109800 documents
# processed 110000 documents
# processed 110200 documents
# processed 110400 documents
# processed 110600 documents
# processed 110800 documents
# processed 111000 documents
# processed 111200 documents
# processed 111400 documents
# processed 111600 documents
# processed 111800 documents
# processed 112000 documents
# processed 112200 documents
# processed 112400 documents
# processed 112600 documents
# processed 112800 documents
# processed 113000 documents
# processed 113200 documents
# processed 113400 documents
# processed 113600 documents
# processed 113800 documents
# processed 114000 documents
# processed 114200 documents
# processed 114400 documents
# processed 114600 documents
# processed 114800 documents
# processed 115000 documents
# processed 115200 documents
# processed 115400 documents
# processed 115600 documents
# processed 115800 documents
# processed 116000 documents
# processed 116200 documents
# processed 116400 documents
# processed 116600 documents
# processed 116800 documents
# processed 117000 documents
# processed 117200 documents
# processed 117400 documents
# processed 117600 documents
# processed 117800 documents
# processed 118000 documents
# processed 118200 documents
# processed 118400 documents
# processed 118600 documents
# processed 118800 documents
# processed 119000 documents
# processed 119200 documents
# processed 119400 documents
# processed 119600 documents
# processed 119800 documents
# processed 120000 documents
# processed 120200 documents
# processed 120400 documents
# processed 120600 documents
# processed 120800 documents
# processed 121000 documents
# processed 121200 documents
# processed 121400 documents
# processed 121600 documents
# processed 121800 documents
# processed 122000 documents
# processed 122200 documents
# processed 122400 documents
# processed 122600 documents
# processed 122800 documents
# processed 123000 documents
# processed 123200 documents
# processed 123400 documents
# processed 123600 documents
# processed 123800 documents
# processed 124000 documents
# processed 124200 documents
# processed 124400 documents
# processed 124600 documents
# processed 124800 documents
# processed 125000 documents
# processed 125200 documents
# processed 125400 documents
# processed 125600 documents
# processed 125800 documents
# processed 126000 documents
# processed 126200 documents
# processed 126400 documents
# processed 126600 documents
# processed 126800 documents
# processed 127000 documents
# processed 127200 documents
# processed 127400 documents
# processed 127600 documents
# processed 127800 documents
# processed 128000 documents
# processed 128200 documents
# processed 128400 documents
# processed 128600 documents
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-957a7c3b54f2> in <module>()
#      41         updates = {'$set': item}
#      42         try:
# ---> 43             col.find_one_and_replace(filters, item, upsert=True)
#      44     #         print('found and replaced')
#      45             fs_and_us['replaced'] += 1
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in find_one_and_replace(self, filter, replacement, projection, sort, upsert, return_document, session, **kwargs)
#    3035         return self.__find_and_modify(filter, projection,
#    3036                                       sort, upsert, return_document,
# -> 3037                                       session=session, **kwargs)
#    3038
#    3039     def find_one_and_update(self, filter, update,
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in __find_and_modify(self, filter, projection, sort, upsert, return_document, array_filters, session, **kwargs)
#    2898
#    2899         return self.__database.client._retryable_write(
# -> 2900             write_concern.acknowledged, _find_and_modify, session)
#    2901
#    2902     def find_one_and_delete(self, filter,
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1278         """Internal retryable write helper."""
#    1279         with self._tmp_session(session) as s:
# -> 1280             return self._retry_with_session(retryable, func, s, None)
#    1281
#    1282     def __reset_server(self, address):
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1231                             raise last_error
#    1232                         retryable = False
# -> 1233                     return func(session, sock_info, retryable)
#    1234             except ServerSelectionTimeoutError:
#    1235                 if is_retrying():
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in _find_and_modify(session, sock_info, retryable_write)
#    2892                                 collation=collation, session=session,
#    2893                                 retryable_write=retryable_write,
# -> 2894                                 user_fields=_FIND_AND_MODIFY_DOC_FIELDS)
#    2895             _check_write_command_response(out)
#    2896
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in _command(self, sock_info, command, slave_ok, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     250                 client=self.__database.client,
#     251                 retryable_write=retryable_write,
# --> 252                 user_fields=user_fields)
#     253
#     254     def __create(self, options, collation, session):
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     587         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     588         except BaseException as error:
# --> 589             self._raise_connection_failure(error)
#     590
#     591     def send_message(self, message, max_doc_size):
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     748             _raise_connection_failure(self.address, error)
#     749         else:
# --> 750             raise error
#     751
#     752     def __eq__(self, other):
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     582                            use_op_msg=self.op_msg_enabled,
#     583                            unacknowledged=unacknowledged,
# --> 584                            user_fields=user_fields)
#     585         except OperationFailure:
#     586             raise
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields)
#     146             response_doc = {"ok": 1}
#     147         else:
# --> 148             reply = receive_message(sock, request_id)
#     149             unpacked_docs = reply.unpack_response(
#     150                 codec_options=codec_options, user_fields=user_fields)
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/network.py in receive_message(sock, request_id, max_message_size)
#     179     # Ignore the response's request id.
#     180     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 181         _receive_data_on_socket(sock, 16))
#     182     # No request_id for exhaust cursor "getMore".
#     183     if request_id is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     238         while bytes_read < length:
#     239             try:
# --> 240                 chunk_length = sock.recv_into(mv[bytes_read:])
#     241             except (IOError, OSError) as exc:
#     242                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
print(len(updated_doc_ids))
# Out:
# 7

# %%
r[0].keys()
# Out:
# dict_keys(['_id', 'instant', 'zipcode', 'forecasts', 'clouds', 'detailed_status', 'humidity', 'pressure', 'rain', 'reference_time', 'snow', 'status', 'temperature', 'weather_code', 'wind', 'weather'])
