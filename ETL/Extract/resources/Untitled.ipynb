# %%
import pandas as pd

# %%
df = pd.read_csv("zip_code_database.csv")

# %%
df.head(11510)
# Out:
#          zip      type  decommissioned primary_city acceptable_cities  \
# 0        501    UNIQUE               0   Holtsville               NaN
# 1        544    UNIQUE               0   Holtsville               NaN
# 2        601  STANDARD               0     Adjuntas               NaN
# 3        602  STANDARD               0       Aguada               NaN
# 4        603  STANDARD               0    Aguadilla             Ramey
# ...      ...       ...             ...          ...               ...
# 11505  27613  STANDARD               0      Raleigh               NaN
# 11506  27614  STANDARD               0      Raleigh               NaN
# 11507  27615  STANDARD               0      Raleigh               NaN
# 11508  27616  STANDARD               0      Raleigh         Brentwood
# 11509  27617  STANDARD               0      Raleigh               NaN
#
#                                      unacceptable_cities state  \
# ...

# %%
df.columns
# Out:
# Index(['zip', 'type', 'decommissioned', 'primary_city', 'acceptable_cities',
#        'unacceptable_cities', 'state', 'county', 'timezone', 'area_codes',
#        'world_region', 'country', 'latitude', 'longitude',
#        'irs_estimated_population_2015'],
#       dtype='object')

# %%
zip_frame = df.loc[lambda df: df['state'] == 'NC']
zip_frame = zip_frame[['zip', 'latitude', 'longitude']].reset_index()
zip_frame.to_csv('zip_list.csv')

# %%
# codes = zip_list['zip']
# codes.to_csv('codes.csv', header=False)

# %%
# zip_frame.head()

# %%
# zip_frame.drop('index', axis=1, inplace=True)
# zip_list = []
# n=0
# for row in zip_frame:
#     n+=1
#     zip_list.append(zip_frame['zip'])
#     print(n)

# %%
zip_list = zip_frame['zip'].tolist()
zip_list[0]
# Out:
# 27006

# %%
def write_list_to_file(zip_list, filename):
    """Write the list to csv file."""

    with open(filename, "w") as z_list:
        z_list.write(",".join(str(z) for z in zip_list))
#         for entry in zip_list:
#             z_list.write(str(entry))
#             z_list.write(",")

# %%
def read_list_from_file(filename):
    """Write the list to csv file."""

    with open(filename, "r") as z_list:
        return z_list.read().strip().split(',')

# %%
filename = 'zip_list.csv'

read_list_from_file(filename)
# Out:
# ['27006',
#  '27007',
#  '27009',
#  '27010',
#  '27011',
#  '27012',
#  '27013',
#  '27014',
#  '27016',
#  '27017',
#  '27018',
#  '27019',
#  '27020',
#  '27021',
#  '27022',
#  '27023',
#  '27024',
#  '27025',
#  '27027',
#  '27028',
#  '27030',
#  '27031',
#  '27040',
#  '27041',
#  '27042',
#  '27043',
#  '27045',
#  '27046',
#  '27047',
#  '27048',
#  '27049',
#  '27050',
#  '27051',
#  '27052',
#  '27053',
#  '27054',
#  '27055',
#  '27094',
#  '27098',
#  '27099',
#  '27101',
#  '27102',
#  '27103',
#  '27104',
#  '27105',
#  '27106',
#  '27107',
#  '27108',
#  '27109',
#  '27110',
#  '27111',
#  '27113',
#  '27114',
#  '27115',
#  '27116',
#  '27117',
#  '27120',
#  '27127',
#  '27130',
#  '27150',
#  '27151',
#  '27152',
#  '27155',
#  '27156',
#  '27157',
#  '27198',
#  '27199',
#  '27201',
#  '27202',
#  '27203',
#  '27204',
#  '27205',
#  '27207',
#  '27208',
#  '27209',
#  '27212',
#  '27213',
#  '27214',
#  '27215',
#  '27216',
#  '27217',
#  '27220',
#  '27228',
# ...

# %%
write_list_to_file(zip_list, filename)
